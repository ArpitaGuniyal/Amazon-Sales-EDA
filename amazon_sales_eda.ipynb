# %% [markdown]
# # **Project Name**    - Amazon Sales Analysis

# %% [markdown]
# ##### **Project Type**    - EDA (Exploratory Data Analysis)
# ##### **Contribution**    - Individual
# ##### **Name -** Arpita Guniyal

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Amazon offers a wide range of products across different categories with varying prices, discounts, customer ratings, and review counts. Understanding customer purchasing behavior and product performance is essential for making informed business decisions. This project aims to perform Exploratory Data Analysis (EDA) on Amazon sales data to identify trends, patterns, and relationships among different product attributes that can help improve pricing strategies, product recommendations, and customer satisfaction.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The objective of this project is to analyze Amazon product data to uncover meaningful insights related to product pricing, discounts, customer ratings, and reviews. The analysis aims to identify high-performing product categories, understand customer preferences, and explore relationships between different variables to support data-driven business decisions.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
pd.set_option("display.max_columns", None)

# %%
# !ls -R
# Out:
# .:
# amazon.csv  sample_data
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %% [markdown]
# ### Dataset Loading

# %%
df = pd.read_csv("amazon.csv")

# %% [markdown]
# ### Dataset First View

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
df.shape
# Out:
# (1465, 16)

# %% [markdown]
# **Observation:** The dataset contains 1465 rows and 16 columns, indicating that it has sufficient data for exploratory analysis.

# %% [markdown]
# ### Dataset Information

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# **Observation:** The statistical summary provides information about the distribution of numerical variables.

# %%
df.describe(include='object')
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# **Observation:** The categorical summary shows the frequency and uniqueness of textual variables such as product name and category.

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Observation:
#
# - The dataset contains **0 duplicate rows**.
# - This indicates that each record is unique, and no duplicate records need to be removed before analysis.

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %%
# Visualizing the missing values

# Create a heatmap to visualize missing values in the dataset
plt.figure(figsize=(12, 6))

sns.heatmap(
    df.isnull(),
    cbar=True,
    cmap='viridis',
    yticklabels=False
)

# Add chart title and labels
plt.title("Missing Values Heatmap")
plt.xlabel("Columns")
plt.ylabel("Records")

# Display the plot
plt.show()

# %%
# Calculate the total and percentage of missing values
missing_values = pd.DataFrame({
    "Missing Values": df.isnull().sum(),
    "Percentage": (df.isnull().sum() / len(df)) * 100
})

# Display only columns with missing values
missing_values[missing_values["Missing Values"] > 0].sort_values(
    by="Missing Values", ascending=False
)
# Out:
#               Missing Values  Percentage
# rating_count               2    0.136519

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ### Observation:
#
# - The dataset contains **1,465 records** and **16 columns**.
# - The missing values heatmap shows that the dataset is almost complete.
# - Only the **`rating_count`** column contains **2 missing values**, while all other columns have no missing values.
# - Since the number of missing values is extremely small (less than 0.2% of the dataset), it will have a negligible impact on the overall analysis.
# - These missing values can be handled easily during the data cleaning stage using an appropriate technique such as imputation or removal.Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
# Dataset Columns

print("Columns in the dataset:\n")

for col in df.columns:
    print(col)
# Out:
# Columns in the dataset:
#
# product_id
# product_name
# category
# discounted_price
# actual_price
# discount_percentage
# rating
# rating_count
# about_product
# user_id
# user_name
# review_id
# review_title
# review_content
# img_link
# product_link

# %%
# Dataset Describe
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
# Statistical summary of the dataset

df.describe(include='all')
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B083342NKJ  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | Column              | Description                                |
# | ------------------- | ------------------------------------------ |
# | product_id          | Unique identifier assigned to each product |
# | product_name        | Name of the product                        |
# | category            | Category and subcategory of the product    |
# | discounted_price    | Selling price after discount               |
# | actual_price        | Original price before discount             |
# | discount_percentage | Percentage discount offered                |
# | rating              | Average customer rating                    |
# | rating_count        | Number of customer ratings                 |
# | about_product       | Product description and features           |
# | user_id             | Unique ID(s) of reviewer(s)                |
# | user_name           | Name(s) of reviewer(s)                     |
# | review_id           | Unique review identifier                   |
# | review_title        | Short title of the review                  |
# | review_content      | Detailed review given by customers         |
# | img_link            | URL of product image                       |
# | product_link        | Amazon product URL                         |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
df.nunique()
# Out:
# product_id             1351
# product_name           1337
# category                211
# discounted_price        550
# actual_price            449
# discount_percentage      92
# rating                   28
# rating_count           1143
# about_product          1293
# user_id                1194
# user_name              1194
# review_id              1194
# review_title           1194
# review_content         1212
# img_link               1412
# product_link           1465
# dtype: int64

# %% [markdown]
# Observations:
#
# * The dataset contains 16 variables describing products, pricing, ratings, reviews and product links.
# * Columns such as product_id, review_id, product_link, and img_link have a very high number of unique values because they uniquely identify products or reviews.
# * The category column contains multiple product categories, making it useful for categorical analysis.
# * Numerical information such as prices, discount percentage and ratings are currently stored as object (string) datatype and will require preprocessing before analysis.
# * Overall, the dataset contains a mix of product details, pricing information and customer review attributes.

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Cleaning and preparing the dataset for analysis

# Create a copy of the original dataset to preserve raw data
df_clean = df.copy()

# Remove the Indian Rupee symbol (₹) and commas from price columns
df_clean['discounted_price'] = (
    df_clean['discounted_price']
    .str.replace('₹', '', regex=False)
    .str.replace(',', '', regex=False)
    .astype(float)
)

df_clean['actual_price'] = (
    df_clean['actual_price']
    .str.replace('₹', '', regex=False)
    .str.replace(',', '', regex=False)
    .astype(float)
)

# Remove the percentage symbol (%) and convert to numeric
df_clean['discount_percentage'] = (
    df_clean['discount_percentage']
    .str.replace('%', '', regex=False)
    .astype(float)
)

# Convert ratings into numeric values
df_clean['rating'] = pd.to_numeric(df_clean['rating'], errors='coerce')

# Remove commas from rating_count and convert to numeric
df_clean['rating_count'] = (
    df_clean['rating_count']
    .str.replace(',', '', regex=False)
)

df_clean['rating_count'] = pd.to_numeric(df_clean['rating_count'], errors='coerce')

# Verify the updated data types
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   float64
#  4   actual_price         1465 non-null   float64
#  5   discount_percentage  1465 non-null   float64
#  6   rating               1464 non-null   float64
#  7   rating_count         1463 non-null   float64
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Observation:
# * Created a separate copy of the dataset (df_clean) to preserve the original data.
# * Converted price columns from string format to numeric by removing the currency symbol (₹) and commas.
# * Converted discount_percentage into numeric values by removing the percentage sign.
# * Converted rating and rating_count columns to numeric format for statistical analysis.
# * The dataset is now suitable for numerical calculations, correlation analysis and visualizations.
# * Only the rating_count column contains two missing values, while all other cleaned columns were converted successfully.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# ### **Univariate Analysis (9 Charts)**

# %% [markdown]
# #### Chart - 1: Distribution of Product Ratings

# %% [markdown]
# Business Question: How are customer ratings distributed across products?

# %%
plt.figure(figsize=(8, 5))

plt.hist(
    df_clean['rating'].dropna(),
    bins=15,
    edgecolor='black'
)

plt.title("Distribution of Product Ratings")
plt.xlabel("Rating")
plt.ylabel("Number of Products")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 1.1 Why did you pick the specific chart?

# %% [markdown]
# A histogram is ideal for visualizing the distribution of a numerical variable. It helps understand how product ratings are spread across different rating values and whether customers generally give high or low ratings.

# %% [markdown]
# ##### 1.2 What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most products have ratings between 4.0 and 4.5.
# * Very few products have ratings below 3.5.
# * The dataset is skewed toward highly rated products.

# %% [markdown]
# ##### 1.3 Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.
# * High ratings indicate that most listed products satisfy customers.
# * Businesses can identify the characteristics of highly rated products and replicate those strategies.
# * Products with unusually low ratings can be investigated to improve customer satisfaction.

# %% [markdown]
# #### Chart - 2: Distribution of Discount Percentage

# %% [markdown]
# Business Question: What discount percentages are most commonly offered?

# %%
plt.figure(figsize=(8,5))

plt.hist(
    df_clean['discount_percentage'].dropna(),
    bins=15,
    edgecolor='black'
)

plt.title("Distribution of Discount Percentage")
plt.xlabel("Discount Percentage (%)")
plt.ylabel("Number of Products")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 2.1 Why did you pick the specific chart?

# %% [markdown]
# A histogram is the most appropriate chart for understanding the distribution of a numerical variable. It shows whether products are concentrated around certain discount ranges or spread evenly across different discounts.

# %% [markdown]
# ##### 2.2 What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most products receive discounts between 40% and 60%.
# * Very few products have extremely low or extremely high discounts.
# * The distribution suggests that Amazon commonly offers moderate discounts rather than very small or exceptionally large discounts.

# %% [markdown]
# ##### 2.3 Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.
# * Understanding the most common discount range helps sellers design competitive pricing strategies.
# * Businesses can benchmark their discounts against the marketplace average.
# * Products with unusually high discounts may indicate clearance sales or lower demand and should be monitored to maintain profitability.

# %% [markdown]
# #### Chart - 3: Top 10 Product Categories

# %% [markdown]
# Business Question: Which product categories contain the largest number of products?

# %%
# Extract only the main category
main_category = df_clean['category'].str.split('|').str[0]

# Count top 10 main categories
top_categories = main_category.value_counts().head(10)

# Create the figure
plt.figure(figsize=(12,6))

# Plot bar chart
top_categories.plot(
    kind='bar',
    edgecolor='black'
)

# Add title and labels
plt.title("Top 10 Product Categories")
plt.xlabel("Category")
plt.ylabel("Number of Products")

# Rotate x-axis labels for readability
plt.xticks(rotation=45, ha='right')

plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 3.1 Why did you pick the specific chart?

# %% [markdown]
# A bar chart is the best choice for comparing the frequency of categorical variables. It clearly shows which product categories contain the highest number of products.

# %% [markdown]
# ##### 3.2 What is/are the insight(s) found from the chart?

# %% [markdown]
# * A few product categories dominate the dataset.
# * The top categories contain significantly more products than the remaining categories.
# * The dataset is not uniformly distributed across all categories.

# %% [markdown]
# ##### 3.3 Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.
#
# * Businesses can identify high-demand product segments.
# * Marketing campaigns can focus on the categories with the largest product presence.
# * Categories with fewer products may represent opportunities for expansion or niche marketing strategies.

# %% [markdown]
# #### Chart - 4: Distribution of Discounted Price

# %% [markdown]
# Business Question: What is the distribution of selling prices after discounts?

# %%
plt.figure(figsize=(10,5))

plt.hist(
    df_clean['discounted_price'],
    bins=30,
    edgecolor='black'
)

plt.title("Distribution of Discounted Prices")
plt.xlabel("Discounted Price (₹)")
plt.ylabel("Number of Products")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 4.1 Why did you pick the specific chart?

# %% [markdown]
# A histogram is ideal for understanding the distribution of numerical data. It helps identify common price ranges, skewness, and the presence of expensive or budget-friendly products.

# %% [markdown]
# ##### 4.2 What is/are the insight(s) found from the chart?

# %% [markdown]
# * The distribution of discounted prices is right-skewed, with a large concentration of products in the lower price ranges.
# * As the discounted price increases, the number of products decreases significantly.
# * Only a small proportion of products are priced at the premium end.

# %% [markdown]
# ##### 4.3 Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.
# * Businesses can understand the dominant pricing segment in the marketplace.
# * Sellers can strategically price their products to remain competitive.
# * Premium-priced products can be analyzed separately to understand their market performance.

# %% [markdown]
# #### Chart - 5: Top 10 Highest Rated Products

# %% [markdown]
# Business Question: Which products have the highest customer engagement?

# %%
# Select the top 10 most reviewed products
top_reviewed = (
    df_clean[['product_name', 'rating_count']]
    .dropna()
    .sort_values(by='rating_count', ascending=False)
    .head(10)
)

# Shorten long product names for better readability
top_reviewed['short_name'] = (
    top_reviewed['product_name']
    .str.slice(0, 45) + "..."
)

# Create the figure
plt.figure(figsize=(12, 7))

# Plot horizontal bar chart
plt.barh(
    top_reviewed['short_name'],
    top_reviewed['rating_count'],
    edgecolor='black'
)

# Add chart title and labels
plt.title("Top 10 Most Reviewed Products")
plt.xlabel("Number of Ratings")
plt.ylabel("Product")

# Display the highest value at the top
plt.gca().invert_yaxis()

plt.grid(axis='x', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart is ideal for comparing products with the highest number of customer ratings. It clearly ranks products by popularity while accommodating long product names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * A small number of products have received significantly more customer ratings than others.
# * These products are likely among the most popular and widely purchased items on Amazon.
# * The gap between the top-reviewed products and the rest suggests that customer attention is concentrated on a limited set of products.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes.
#
# * Businesses can identify products that have achieved high customer engagement.
# * Popular products can be prioritized in marketing campaigns and recommendation systems.
# * Analyzing the features of these products can help sellers improve the visibility and sales of similar products.

# %% [markdown]
# #### Chart - 6: Top 10 Highest Discounted Products

# %% [markdown]
# Business Question: Which products offer the largest discounts?

# %%
# Select top 10 products with highest discounts
top_discount = (
    df_clean[['product_name', 'discount_percentage']]
    .sort_values(by='discount_percentage', ascending=False)
    .head(10)
)

# Shorten long product names
top_discount['short_name'] = (
    top_discount['product_name']
    .str.slice(0, 45) + "..."
)

# Create figure
plt.figure(figsize=(12, 7))

plt.barh(
    top_discount['short_name'],
    top_discount['discount_percentage'],
    edgecolor='black'
)

plt.title("Top 10 Products with Highest Discount Percentage")
plt.xlabel("Discount Percentage (%)")
plt.ylabel("Product")

plt.gca().invert_yaxis()

plt.grid(axis='x', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart clearly compares products based on discount percentage while accommodating long product names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some products receive exceptionally high discounts compared to others.
# * High discounts may be used to boost sales, clear inventory, or compete in crowded categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes
# * Businesses can identify aggressive pricing strategies.
# * Large discounts may increase sales volume but could reduce profit margins if not managed carefully.

# %% [markdown]
# #### Chart - 7: Distribution of Customer Rating Count

# %% [markdown]
# Business Question: How are customer review counts distributed across products?

# %%
plt.figure(figsize=(10, 5))

plt.hist(
    df_clean['rating_count'].dropna(),
    bins=30,
    edgecolor='black'
)

plt.xscale('log')   # Makes the x-axis logarithmic

plt.title("Distribution of Customer Rating Count")
plt.xlabel("Number of Ratings")
plt.ylabel("Number of Products")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram helps visualize how customer engagement (ratings received) is distributed across products.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most products have relatively few ratings.
# * Only a small number of products receive very high customer engagement.
# * The distribution is heavily right-skewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Popular products attract significantly more customer interaction.
# * Businesses can study these products to understand what drives customer engagement and replicate those strategies.

# %% [markdown]
# #### Chart - 8: Top 10 Most Expensive Products (Actual Price)

# %% [markdown]
# Business Question: Which products belong to the premium price segment?

# %%
# Select top 10 most expensive products
top_expensive = (
    df_clean[['product_name', 'actual_price']]
    .sort_values(by='actual_price', ascending=False)
    .head(10)
)

# Shorten long product names
top_expensive['short_name'] = (
    top_expensive['product_name']
    .str.slice(0, 45) + "..."
)

# Create figure
plt.figure(figsize=(12,7))

plt.barh(
    top_expensive['short_name'],
    top_expensive['actual_price'],
    edgecolor='black'
)

plt.title("Top 10 Most Expensive Products")
plt.xlabel("Actual Price (₹)")
plt.ylabel("Product")

plt.gca().invert_yaxis()

plt.grid(axis='x', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen because it is ideal for comparing the prices of the top 10 most expensive products. It makes it easy to rank products from highest to lowest price while accommodating long product names.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Sony Bravia 65-inch 4K Ultra HD Smart TV is the most expensive product in the dataset.
# * Most of the top 10 expensive products are Smart TVs from brands such as Sony, * Samsung, LG, Vu, Xiaomi, and OnePlus.
# * The prices of these premium products range approximately from ₹65,000 to ₹1,40,000.
# * Premium televisions dominate the highest-priced products, indicating that this category contributes significantly to the high-value segment.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# * The insights help identify premium products that generate higher revenue per sale.
# * Businesses can focus marketing efforts on these high-value products and develop targeted promotional strategies for premium customers.
# * Understanding which brands dominate the premium segment helps in inventory planning and pricing decisions.
#
# **Potential Negative Impact:**
#
# * Premium products have a smaller target audience due to their high prices, which may result in lower sales volume compared to affordable products.
# * Overemphasizing expensive products without maintaining a balanced product portfolio could reduce overall customer reach and sales.

# %% [markdown]
# #### Chart - 9: Box Plot of Discounted Prices

# %%
plt.figure(figsize=(8,5))

plt.boxplot(
    df_clean['discounted_price'].dropna(),
    vert=False
)

plt.title("Box Plot of Discounted Prices")
plt.xlabel("Discounted Price (₹)")

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot was chosen because it effectively summarizes the distribution of discounted prices by showing the median, spread, and presence of outliers. It provides a clearer understanding of price variation than a histogram.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most products are concentrated within a lower discounted price range.
# * A small number of products have exceptionally high discounted prices, appearing as outliers.
# * The distribution of discounted prices is positively skewed, with relatively few premium-priced products.
# * The large spread indicates considerable variation in product pricing across the dataset.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Businesses can use pricing insights to segment products into budget, mid-range, and premium categories for targeted marketing.
# * Identifying premium-priced products helps develop specialized pricing and promotional strategies for different customer segments.
#
# **Potential Negative Impact:**
#
# * Extremely high-priced products may experience lower sales volumes because they appeal to a smaller customer base.
# * A wide variation in prices may require different marketing approaches for different customer segments, increasing pricing and promotional complexity.

# %% [markdown]
# ### **Bivariate Analysis (7 Charts)**

# %% [markdown]
# #### Chart - 10: Average Rating by Main Category

# %% [markdown]
# Business Question: Which product categories receive the highest average customer ratings?

# %%
# Create the main category column
df_clean['main_category'] = df_clean['category'].str.split('|').str[0]

# Calculate average rating for each category
avg_rating = (
    df_clean.groupby('main_category')['rating']
    .mean()
    .sort_values(ascending=False)
)

# Plot
plt.figure(figsize=(10,6))

avg_rating.plot(
    kind='bar',
    edgecolor='black'
)

plt.title("Average Product Rating by Category")
plt.xlabel("Category")
plt.ylabel("Average Rating")

plt.xticks(rotation=45, ha='right')

plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart was chosen because it clearly compares the average customer ratings across different product categories. It helps identify which categories perform best in terms of customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Average ratings vary across product categories.
# * Some categories consistently receive higher customer ratings, indicating better customer satisfaction.
# * Lower-rated categories may indicate areas where product quality or customer experience can be improved.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
# * Businesses can identify high-performing categories and focus marketing efforts on them.
# * Categories with high average ratings can be promoted to increase customer trust and sales.
# * Lower-rated categories can be analyzed to improve product quality and customer satisfaction.
#
# **Potential Negative Impact:**
# * Categories with consistently lower ratings may negatively affect customer perception and reduce repeat purchases.
# * Ignoring poorly performing categories may lead to declining customer confidence and lower sales over time.

# %% [markdown]
# #### Chart - 11: Relationship Between Actual Price and Discounted Price

# %% [markdown]
# Business Question: Do products with higher actual prices also have higher discounted prices?

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df_clean['actual_price'],
    df_clean['discounted_price'],
    alpha=0.6
)

plt.title("Actual Price vs Discounted Price")
plt.xlabel("Actual Price (₹)")
plt.ylabel("Discounted Price (₹)")

plt.grid(alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is ideal for examining the relationship between two numerical variables. It helps identify trends, correlations, clusters, and any unusual observations between actual price and discounted price.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Products with higher actual prices generally have higher discounted prices.
# * A positive relationship exists between actual and discounted prices.
# * Most products follow a consistent pricing pattern, while a few products appear as outliers with exceptionally high prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. The relationship helps businesses evaluate whether discounts are being applied consistently across different price ranges. Products that deviate significantly from the overall trend may require pricing review. Inconsistent pricing strategies could reduce customer trust and negatively affect sales.

# %% [markdown]
# #### Chart - 12: Rating vs Customer Rating Count

# %% [markdown]
# Business Question: Do products with higher ratings also receive more customer reviews?

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    df_clean['rating_count'],
    df_clean['rating'],
    alpha=0.6
)

plt.title("Rating vs Customer Rating Count")
plt.xlabel("Customer Rating Count")
plt.ylabel("Product Rating")

plt.grid(alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot is suitable for examining the relationship between customer ratings and the number of reviews. It helps identify whether highly rated products also tend to attract more customer feedback.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Products with a high number of reviews generally maintain ratings between 4.0 and 4.5.
# * Many products have excellent ratings despite receiving relatively few reviews.
# * The relationship between rating and review count is weak, indicating that popularity does not always guarantee higher ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Businesses can identify highly rated products that deserve greater visibility despite having fewer reviews. Products with many reviews but lower ratings may indicate quality issues that should be addressed to maintain customer satisfaction and sales.

# %% [markdown]
# #### Chart - 13: Average Discount Percentage by Main Category

# %% [markdown]
# Business Question: Which product categories receive the highest average discounts?

# %%
avg_discount = (
    df_clean.groupby('main_category')['discount_percentage']
    .mean()
    .sort_values(ascending=False)
)

plt.figure(figsize=(10,6))

avg_discount.plot(
    kind='bar',
    edgecolor='black'
)

plt.title("Average Discount Percentage by Main Category")
plt.xlabel("Main Category")
plt.ylabel("Average Discount (%)")

plt.xticks(rotation=45, ha='right')

plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares the average discount percentage across different product categories, making it easy to identify categories with the most aggressive discount strategies.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some categories consistently offer higher average discounts than others.
# * Categories with lower discounts may rely more on product demand than promotional pricing.
# * The variation in discounts suggests different pricing and marketing strategies across categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes. Businesses can evaluate whether discount strategies are aligned with customer demand and sales objectives. Categories receiving consistently high discounts should be monitored to ensure profitability, while categories with low discounts may have opportunities for promotional campaigns to increase sales.

# %% [markdown]
# #### Chart - 14: Average Actual Price by Main Category

# %% [markdown]
# Business Question:  Which product categories have the highest average actual (original) prices?

# %%
# Calculate average actual price for each main category
avg_actual_price = (
    df_clean.groupby('main_category')['actual_price']
    .mean()
    .sort_values(ascending=False)
)

# Create figure
plt.figure(figsize=(10,6))

# Plot
avg_actual_price.plot(
    kind='bar',
    edgecolor='black'
)

# Add title and labels
plt.title("Average Actual Price by Main Category")
plt.xlabel("Main Category")
plt.ylabel("Average Actual Price (₹)")

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Add grid
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is suitable for comparing the average actual prices across product categories. It provides a clear comparison of which categories belong to the premium price segment.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some product categories have significantly higher average original prices than others.
# * Premium categories are priced much higher before discounts are applied.
# * The pricing differences indicate that different categories target different customer segments.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Businesses can identify premium categories and develop pricing, inventory, and marketing strategies tailored to high-value customers.
# * Understanding category-wise pricing supports better product positioning and revenue planning.
#
# **Potential Negative Impact:**
#
# * Categories with very high prices may experience lower sales volumes because they cater to a smaller customer base.
# * Overpricing without providing sufficient value may discourage potential buyers.

# %% [markdown]
# #### Chart - 15: Average Discounted Price by Main Category

# %% [markdown]
# Business Question:  Which product categories remain the most expensive even after discounts?

# %%
# Calculate average discounted price for each main category
avg_discounted_price = (
    df_clean.groupby('main_category')['discounted_price']
    .mean()
    .sort_values(ascending=False)
)

# Create figure
plt.figure(figsize=(10,6))

# Plot
avg_discounted_price.plot(
    kind='bar',
    edgecolor='black'
)

# Add title and labels
plt.title("Average Discounted Price by Main Category")
plt.xlabel("Main Category")
plt.ylabel("Average Discounted Price (₹)")

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right')

# Add grid
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart clearly compares the average selling prices across product categories after discounts have been applied. It helps identify categories that continue to command premium prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some categories remain relatively expensive even after discounts.
# * Discounts reduce prices, but premium categories still maintain higher selling prices.
# * The difference between original and discounted prices varies across categories.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Businesses can evaluate whether their discount strategies are effective while maintaining profitability.
# * Premium categories can be marketed differently from budget-friendly categories.
#
# **Potential Negative Impact:**
#
# * If discounted prices remain too high, customers may switch to lower-priced alternatives.
# * Excessive discounts without sufficient sales growth may reduce overall profit margins.

# %% [markdown]
# #### Chart - 16: Average Customer Rating Count by Main Category

# %% [markdown]
# Business Question:  Which product categories receive the highest customer engagement (based on rating count)?

# %%
# Calculate average rating count for each main category
avg_rating_count = (
    df_clean.groupby('main_category')['rating_count']
    .mean()
    .sort_values(ascending=False)
)

# Create figure
plt.figure(figsize=(10,6))

# Plot
avg_rating_count.plot(
    kind='bar',
    edgecolor='black'
)

# Add title and labels
plt.title("Average Customer Rating Count by Main Category")
plt.xlabel("Main Category")
plt.ylabel("Average Rating Count")

# Rotate labels
plt.xticks(rotation=45, ha='right')

# Add grid
plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares the average number of customer ratings across different product categories. It clearly highlights which categories receive the greatest customer engagement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some categories receive significantly more customer ratings than others.
# * Higher average rating counts indicate greater customer engagement and product popularity.
# * Categories with lower engagement may require improved marketing or increased product visibility.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# **Positive Business Impact:**
#
# * Businesses can focus on highly engaged categories for promotional campaigns and inventory planning.
# * Understanding customer engagement helps prioritize categories that generate the most interest and feedback.
#
# **Potential Negative Impact:**
#
# * Categories with consistently low engagement may experience lower visibility and sales.
# * Ignoring these categories could result in missed opportunities for growth and customer acquisition.

# %% [markdown]
# ### **Multivariate Analysis (5 Charts)**

# %% [markdown]
# #### Chart - 17 - Correlation Heatmap

# %% [markdown]
# Business Question: Which numerical variables are positively or negatively correlated?

# %%
import seaborn as sns

# Select numerical columns
corr_data = df_clean[
    ['actual_price',
     'discounted_price',
     'discount_percentage',
     'rating',
     'rating_count']
]

# Compute correlation matrix
corr_matrix = corr_data.corr()

# Plot heatmap
plt.figure(figsize=(8,6))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='Blues',
    fmt=".2f"
)

plt.title("Correlation Heatmap of Numerical Variables")

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is an effective way to visualize the relationships between multiple numerical variables simultaneously. It helps identify strong positive or negative correlations that may not be obvious from individual charts.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Actual price and discounted price are expected to show a strong positive correlation.
# * Discount percentage may have a negative relationship with discounted price.
# * Rating and rating count generally exhibit weak correlations with pricing variables.
# * The heatmap quickly highlights which variables are closely related and which are largely independent.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?

# %% [markdown]
# Positive Business Impact:
#
# * Businesses can understand how pricing variables interact and make informed pricing decisions.
# * Strong correlations help identify predictable relationships that can support pricing and promotional strategies.
#
# Potential Negative Impact:
#
# * Weak relationships between ratings and pricing suggest that reducing prices alone may not improve customer satisfaction.
# * Relying only on discounts without improving product quality may not lead to better customer reviews or engagement.

# %% [markdown]
# #### Chart - 18: Average Rating by Discount Range

# %% [markdown]
# Business Question: Do products with higher discounts receive better customer ratings?

# %%
# Create discount ranges
discount_bins = [0, 20, 40, 60, 80, 100]
discount_labels = ['0-20%', '21-40%', '41-60%', '61-80%', '81-100%']

df_clean['discount_range'] = pd.cut(
    df_clean['discount_percentage'],
    bins=discount_bins,
    labels=discount_labels,
    include_lowest=True
)

# Calculate average rating for each discount range
avg_rating_discount = (
    df_clean.groupby('discount_range')['rating']
    .mean()
)

# Plot
plt.figure(figsize=(8,5))

avg_rating_discount.plot(
    kind='bar',
    edgecolor='black'
)

plt.title("Average Rating by Discount Range")
plt.xlabel("Discount Range")
plt.ylabel("Average Rating")

plt.xticks(rotation=0)

plt.grid(axis='y', alpha=0.3)

plt.tight_layout()

plt.show()
# Out:
# /tmp/ipykernel_17918/187701556.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_clean.groupby('discount_range')['rating']

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart effectively compares the average customer ratings across different discount ranges. It helps determine whether larger discounts influence customer satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Average ratings vary across different discount ranges.
# * Higher discounts do not necessarily result in higher customer ratings.
# * Customer satisfaction depends on multiple factors beyond pricing.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?

# %% [markdown]
# Positive Business Impact:
#
# * Businesses can evaluate whether offering larger discounts improves customer satisfaction.
# * The findings help optimize pricing and promotional strategies without relying solely on heavy discounts.
#
# Potential Negative Impact:
#
# * If high discounts do not improve ratings, excessive discounting may reduce profit margins without increasing customer satisfaction.

# %% [markdown]
# #### Chart - 19: Box Plot of Ratings by Main Category

# %% [markdown]
# Business Question: Which product categories have the most consistent customer ratings?

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    x='main_category',
    y='rating',
    data=df_clean
)

plt.title("Distribution of Ratings by Main Category")
plt.xlabel("Main Category")
plt.ylabel("Rating")

plt.xticks(rotation=45, ha='right')

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot summarizes the distribution of ratings within each category, showing the median, spread, and potential outliers. It is useful for comparing rating consistency across categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some categories have consistently high ratings with little variation.
# * Other categories show a wider spread, indicating mixed customer experiences.
# * Outliers highlight products with unusually high or low ratings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?

# %% [markdown]
# Positive Business Impact:
#
# * Businesses can identify categories with consistently high customer satisfaction and use them as benchmarks.
# * Categories with greater variation can be investigated to improve product quality and customer experience.
#
# Potential Negative Impact:
#
# * Categories with inconsistent ratings may reduce customer trust if quality varies significantly between products.

# %% [markdown]
# #### Chart - 20: Category-wise Price Distribution

# %% [markdown]
# Business Question: How does the distribution of discounted prices vary across different product categories?

# %%
plt.figure(figsize=(12,6))

sns.boxplot(
    x='main_category',
    y='discounted_price',
    data=df_clean
)

plt.title("Category-wise Distribution of Discounted Prices")
plt.xlabel("Main Category")
plt.ylabel("Discounted Price (₹)")

plt.xticks(rotation=45, ha='right')

plt.tight_layout()

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A box plot is effective for comparing the distribution of discounted prices across different product categories. It displays the median, spread, and outliers, making it easier to understand pricing patterns within each category.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Some categories have a much wider range of discounted prices than others.
# * Certain categories contain several high-priced outlier products even after discounts.
# * The median discounted price differs across categories, indicating distinct pricing strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth?

# %% [markdown]
# Positive Business Impact:
#
# * Businesses can better understand pricing variations across categories and develop category-specific pricing and promotional strategies.
# * Categories with wide price ranges can be segmented into budget and premium offerings to target different customer groups.
#
# Potential Negative Impact:
#
# * Large price variations within a category may confuse customers if products are not clearly differentiated.
# * Premium-priced outliers may experience lower demand if customers perceive them as offering poor value compared to alternatives.

# %% [markdown]
# #### Chart - 21: Pair Plot of Numerical Variables

# %% [markdown]
# Business Question: What relationships and distributions exist among the key numerical variables in the dataset?

# %%
# Select numerical columns
pairplot_data = df_clean[
    [
        'actual_price',
        'discounted_price',
        'discount_percentage',
        'rating',
        'rating_count'
    ]
]

# Create pair plot
sns.pairplot(
    pairplot_data,
    diag_kind='hist'
)

plt.show()

# %%
sns.pairplot(df_clean)

# %% [markdown]
# ##### 21.1 Why did you pick the specific chart?

# %% [markdown]
# A pair plot provides a comprehensive view of the relationships between multiple numerical variables in a single visualization. It displays scatter plots for each pair of variables and histograms along the diagonal, making it useful for identifying correlations, distributions, clusters, and potential outliers.

# %% [markdown]
# ##### 21.2 What is/are the insight(s) found from the chart?

# %% [markdown]
# * Actual Price and Discounted Price show a strong positive relationship, indicating that higher-priced products generally remain more expensive even after discounts.
# * Rating shows relatively little correlation with pricing variables, suggesting that customer satisfaction is influenced by factors beyond price.
# * Rating Count varies widely across products, with only a few products receiving exceptionally high numbers of reviews.
# * The diagonal histograms reveal that most numerical variables are right-skewed, with many lower-valued observations and relatively few high-value outliers.

# %% [markdown]
# ##### 21.3 Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive Business Impact:
#
# * The pair plot helps businesses quickly identify relationships among pricing, discounts, ratings, and customer engagement, supporting data-driven pricing and marketing decisions.
# * Understanding these relationships enables businesses to design better promotional strategies and prioritize products based on both customer response and pricing characteristics.
#
# Potential Negative Impact:
#
# * The weak relationship between discounts, prices, and customer ratings suggests that simply lowering prices may not significantly improve customer satisfaction.
# * Products with consistently low ratings or very low customer engagement should be investigated, as they may negatively affect sales and brand perception if left unaddressed.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
